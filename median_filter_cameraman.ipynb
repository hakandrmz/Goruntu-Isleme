# %%
def convert_rgb_to_gray_level(im_1):
    m = im_1.shape[0]
    n = im_1.shape[1]
    im_2 = np.zeros((m,n))
    for i in range(m):
        for j in range(n):
            im_2[i,j] = get_distance(im_1[i,j,:])
    return im_2
def get_distance(v, w = [1/3, 1/3, 1/3]):
    a, b, c = v[0], v[1], v[2]
    w1, w2, w3 = w[0], w[1], w[2]
    d = ((a**2) * w1 + (b**2) * w2 + (c**2) * w3)**.5
    return d

def get_default_mask_for_mean():
    return np.array([1,1,1,1,1,1,1,1,1]).reshape(3,3)/9

def apply_mask(part_of_image):
    mask=get_default_mask_for_mean()
    return sum(sum(part_of_image*mask))

# %%
import os
os.getcwd(),os.listdir()
# Out:
# ('C:\\Users\\Hakan',
#  ['..bash_profile.un~',
#   '.3T',
#   '.android',
#   '.AndroidStudio4.0',
#   '.atom',
#   '.bash_history',
#   '.bash_profile',
#   '.bash_profile.swp',
#   '.bash_profile~',
#   '.conda',
#   '.condarc',
#   '.config',
#   '.dbshell',
#   '.docker',
#   '.dotnet',
#   '.emulator_console_auth_token',
#   '.gradle',
#   '.idlerc',
#   '.ipynb_checkpoints',
#   '.ipython',
#   '.jupyter',
#   '.matplotlib',
#   '.mongodb',
#   '.mongorc.js',
#   '.node_repl_history',
#   '.Origin',
#   '.packettracer',
#   '.pylint.d',
#   '.QtWebEngineProcess',
#   '.spyder-py3',
#   '.templateengine',
#   '.viminfo',
#   '.vscode',
#   '3D Objects',
#   'anaconda3',
#   'ansel',
#   'AppData',
#   'Application Data',
#   'Belgelerim',
#   'camera.png',
#   'cameraman.jpg',
#   'canakkale.jpg',
#   'canakkale1.jpg',
#   'canakkale2.jpg',
#   'Cisco Packet Tracer 7.3.1',
#   'Contacts',
#   'Cookies',
#   'CSECDViewer',
#   'Desktop',
#   'Documents',
#   'Downloads',
#   'Favorites',
#   'Google Drive',
#   'goruntu_isleme_hafta1.ipynb',
#   'IntelGraphicsProfiles',
#   'Links',
#   'Local Settings',
#   'median_filter_cameraman.ipynb',
#   'MicrosoftEdgeBackups',
#   'Music',
#   'mysite',
#   'NetHood',
#   'NTUSER.DAT',
#   'ntuser.dat.LOG1',
#   'ntuser.dat.LOG2',
#   'NTUSER.DAT{68a45b05-f97c-11ea-9b49-9cfce8146a2b}.TM.blf',
#   'NTUSER.DAT{68a45b05-f97c-11ea-9b49-9cfce8146a2b}.TMContainer00000000000000000001.regtrans-ms',
#   'NTUSER.DAT{68a45b05-f97c-11ea-9b49-9cfce8146a2b}.TMContainer00000000000000000002.regtrans-ms',
#   'ntuser.ini',
#   'OneDrive',
#   'Pictures',
#   'Postman',
#   'PrintHood',
#   'Recent',
#   'Saved Games',
#   'Searches',
#   'SendTo',
#   'source',
#   'Start Menu',
#   'Templates',
#   'Untitled Folder',
#   'Untitled.ipynb',
#   'Untitled1.ipynb',
#   'Untitled2.ipynb',
#   'Untitled3.ipynb',
#   'Untitled4.ipynb',
#   'Untitled5.ipynb',
#   'Videos',
#   'vimfiles',
#   '_.swo',
#   '_.swp',
#   '_viminfo'])

# %%
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
import numpy as np
im_1=mpimg.imread('camera.png')
im_2=convert_rgb_to_gray_level(im_1)
# %matplotlib inline
plt.figure(figsize=(20,20))
plt.subplot(1,3,1),plt.imshow(im_1)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x27119cd9fa0>,
#  <matplotlib.image.AxesImage at 0x27119f623d0>)

# %%
def get_default_mask_for_mean():
    return np.array([1,1,1,1,1,1,1,1,1]).reshape(3,3)/9

def apply_mask(part_of_image):
    mask=get_default_mask_for_mean()
    return sum(sum(part_of_image*mask))
def get_median_for_55(poi):
    s_1=poi.reshape(1,25)
    s_1.sort()
    return(s_1[0,13])
def get_median(poi):
    s_1=poi.reshape(1,9)
    s_1.sort()
    return s_1[0,4]
def get_mean_filter_for_55(im_1):
    #im_1=plt.imread('')
    m=im_1.shape[0]
    n=im_1.shape[1]
    im_2=np.zeros((m,n))
    for i in range(3,m-3):
        for j in range(3,n-3):
            #i=10 j=10
            poi = im_1[i-2:i+3,j-2:j+3]
            im_2[i,j]=get_median_for_55(poi)
    return im_2

def get_mean_filter(im_1):
    #im_1=plt.imread('')
    m=im_1.shape[0]
    n=im_1.shape[1]
    im_2=np.zeros((m,n))
    for i in range(1,m-1):
        for j in range(1,n-1):
            #i=10 j=10
            poi = im_1[i-1:i+2,j-1:j+2]
            im_2[i,j]=get_median(poi)
    return im_2

# %%
apply_mask(im_2[1:4,1:4])
# Out:
# 0.615686297416687

# %%
im_55=get_mean_filter_for_55(im_2)

# %%
im_555=get_mean_filter(im_2)
plt.figure(figsize=(20,20))
plt.subplot(1,2,2),plt.imshow(im_555,cmap='gray')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x2711fd85970>,
#  <matplotlib.image.AxesImage at 0x2711dcb1910>)
